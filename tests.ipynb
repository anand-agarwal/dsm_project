# %%
import pandas as pd

df = pd.read_csv('output_datasets_2001/df_religion_state_2001.csv')
print(df.columns.tolist())
# Out:
# ['state_name', 'age_bracket', 'state_code', 'Below_primary_share_buddhist_female', 'Below_primary_share_christian_female', 'Below_primary_share_hindu_female', 'Below_primary_share_jain_female', 'Below_primary_share_muslim_female', 'Below_primary_share_sikh_female', 'Illiteracy_rate_buddhist_female', 'Illiteracy_rate_buddhist_male', 'Illiteracy_rate_christian_female', 'Illiteracy_rate_christian_male', 'Illiteracy_rate_hindu_female', 'Illiteracy_rate_hindu_male', 'Illiteracy_rate_jain_female', 'Illiteracy_rate_jain_male', 'Illiteracy_rate_muslim_female', 'Illiteracy_rate_muslim_male', 'Illiteracy_rate_sikh_female', 'Illiteracy_rate_sikh_male', 'Literacy_rate_buddhist_female', 'Literacy_rate_buddhist_male', 'Literacy_rate_christian_female', 'Literacy_rate_christian_male', 'Literacy_rate_hindu_female', 'Literacy_rate_hindu_male', 'Literacy_rate_jain_female', 'Literacy_rate_jain_male', 'Literacy_rate_muslim_female', 'Literacy_rate_muslim_male', 'Literacy_rate_sikh_female', 'Literacy_rate_sikh_male', 'Middle_school_share_buddhist_female', 'Middle_school_share_christian_female', 'Middle_school_share_hindu_female', 'Middle_school_share_jain_female', 'Middle_school_share_muslim_female', 'Middle_school_share_sikh_female']

# %%
import os
print(os.listdir('output_datasets_2001/'))
print(os.listdir('output_datasets_2011/'))
# Out:
# ['df_SC_state_2001.csv', 'df_ST_female.csv', 'df_total_female.csv', 'df_total_state_2001.csv', 'df_ST_male.csv', 'df_religion_male.csv', 'df_SC_female.csv', 'df_religion_female.csv', 'df_ST_state_2001.csv', 'df_SC_male.csv', 'df_total_male.csv', 'df_religion_state_2001.csv']
# ['df_ST_female.csv', 'df_total_state_2011.csv', 'df_total_female.csv', 'df_SC_state_2011.csv', 'df_ST_male.csv', 'df_religion_male.csv', 'df_ST_state_2011.csv', 'df_SC_female.csv', 'df_religion_female.csv', 'df_religion_state_2011.csv', 'df_SC_male.csv', 'df_total_male.csv']

# %%
df = pd.read_csv('output_datasets_2001/df_religion_female.csv')
print(df.columns.tolist())
print(df.head(2))
# Out:
# ['state_name', 'age_bracket', 'state_code', 'Below_primary_share_buddhist_female', 'Below_primary_share_christian_female', 'Below_primary_share_hindu_female', 'Below_primary_share_jain_female', 'Below_primary_share_muslim_female', 'Below_primary_share_sikh_female', 'Illiteracy_rate_buddhist_female', 'Illiteracy_rate_christian_female', 'Illiteracy_rate_hindu_female', 'Illiteracy_rate_jain_female', 'Illiteracy_rate_muslim_female', 'Illiteracy_rate_sikh_female', 'Literacy_rate_buddhist_female', 'Literacy_rate_christian_female', 'Literacy_rate_hindu_female', 'Literacy_rate_jain_female', 'Literacy_rate_muslim_female', 'Literacy_rate_sikh_female', 'Middle_school_share_buddhist_female', 'Middle_school_share_christian_female', 'Middle_school_share_hindu_female', 'Middle_school_share_jain_female', 'Middle_school_share_muslim_female', 'Middle_school_share_sikh_female']
#   state_name  age_bracket  state_code  Below_primary_share_buddhist_female  \
# 0      INDIA  age_below10           0                               97.277
# 1      INDIA    age_10_13           0                               37.372
#
#    Below_primary_share_christian_female  Below_primary_share_hindu_female  \
# 0                               96.0714                           96.5072
# 1                               34.4128                           41.1577
#
#    Below_primary_share_jain_female  Below_primary_share_muslim_female  \
# 0                          96.3508                            95.1018
# 1                          24.2432                            47.3565
#
#    Below_primary_share_sikh_female  Illiteracy_rate_buddhist_female  ...  \
# 0                          97.3683                          74.5376  ...
# 1                          42.5514                           8.9318  ...
#
#    Literacy_rate_hindu_female  Literacy_rate_jain_female  \
# 0                     21.6549                    30.1853
# 1                     77.8133                    98.2203
#
#    Literacy_rate_muslim_female  Literacy_rate_sikh_female  \
# 0                      18.4618                    27.6318
# 1                      69.9948                    88.6715
#
#    Middle_school_share_buddhist_female  Middle_school_share_christian_female  \
# 0                               0.0000                                0.0000
# 1                               5.8034                                8.9225
#
#    Middle_school_share_hindu_female  Middle_school_share_jain_female  \
# 0                            0.0000                           0.0000
# 1                            7.0882                          12.9119
#
#    Middle_school_share_muslim_female  Middle_school_share_sikh_female
# 0                             0.0000                            0.000
# 1                             5.7851                            5.782
#
# [2 rows x 27 columns]

# %%
df_rel_2001 = pd.read_csv('output_datasets_2001/df_religion_state_2001.csv').merge(
    pd.read_csv('output_datasets_2001/df_religion_female.csv'),
    on=['state_name', 'age_bracket']
)

# %%
df = pd.read_csv('output_datasets_2001/df_total_female.csv')
cmpr_cols = [c for c in df.columns if 'CMPR' in c or 'cmpr' in c.lower()]
print(cmpr_cols)
# Out:
# ['CMPR_agri_labourers_female', 'CMPR_below_primary_female', 'CMPR_cultivators_female', 'CMPR_household_industry_female', 'CMPR_illiterate_female', 'CMPR_main_workers_female', 'CMPR_matric_female', 'CMPR_middle_female', 'CMPR_non_workers_female', 'CMPR_other_workers_female', 'CMPR_primary_female', 'CMPR_total_female']

# %%
df = pd.read_csv('output_datasets_2001/df_total_state_2001.csv')
cmpr_cols = [c for c in df.columns if 'CMPR' in c or 'cmpr' in c.lower()]
print(cmpr_cols)
# Out:
# ['CMPR_agri_labourers_female', 'CMPR_agri_labourers_male', 'CMPR_below_primary_female', 'CMPR_below_primary_male', 'CMPR_cultivators_female', 'CMPR_cultivators_male', 'CMPR_household_industry_female', 'CMPR_household_industry_male', 'CMPR_illiterate_female', 'CMPR_illiterate_male', 'CMPR_main_workers_female', 'CMPR_main_workers_male', 'CMPR_matric_female', 'CMPR_matric_male', 'CMPR_middle_female', 'CMPR_middle_male', 'CMPR_non_workers_female', 'CMPR_non_workers_male', 'CMPR_other_workers_female', 'CMPR_other_workers_male', 'CMPR_primary_female', 'CMPR_primary_male', 'CMPR_total_female', 'CMPR_total_male']

# %%
def compute_religion_cmpr_2001(raw_path):
    """
    Computes religion-specific CMPR from C-03_Appendix_states.csv (2001 raw census).
    Returns a wide DataFrame with state_code + CMPR_{religion}_{gender} columns.
    The 'Less than 18' age group maps to your age_14_17 bracket.
    """
    df_raw = pd.read_csv(raw_path)
    religions = ['Hindu', 'Muslim', 'Christian', 'Sikh', 'Buddhist', 'Jain']
    df_f = df_raw[
        (df_raw['Total/ | Rural/ | Urban/'] == 'Total') &
        (df_raw['Age- | group | 1'] == 'Less than 18') &
        (df_raw['Religion'].isin(religions))
    ].copy()
    df_f['state_code'] = df_f['State | Code'].astype(int)
    df_f['CMPR_female'] = (df_f['Females | 10'] / df_f['Females | 4'] * 1000).round(4)
    df_f['CMPR_male']   = (df_f['Males | 9']    / df_f['Males | 3']   * 1000).round(4)
    df_f['rel'] = df_f['Religion'].str.lower()
    cmpr_wide = df_f.pivot_table(index='state_code', columns='rel',
                                  values=['CMPR_female', 'CMPR_male'], aggfunc='first')
    cmpr_wide.columns = [f'CMPR_{rel}_{g.split("_")[1]}' for g, rel in cmpr_wide.columns]
    return cmpr_wide.reset_index()

# %%
RAW_2001_PATH = 'raw_data/2001/C-03_Appendix_states.csv'  # add this near your other path constants

# In main():
cmpr_2001 = compute_religion_cmpr_2001(RAW_2001_PATH)
df_rel_2001 = pd.read_csv(REL_PATH_2001).merge(cmpr_2001, on='state_code', how='left')
df_rel_2011 = pd.read_csv(REL_PATH_2011)  # already has CMPR columns

# %%
import pandas as pd
df = pd.read_csv('output_datasets_2011/df_total_state_2011.csv')
print(df.columns.tolist())
# Out:
# ['state_name', 'age_bracket', 'state_code', 'Below_primary_share_total_female', 'Below_primary_share_total_male', 'CMPR_agri_labourers_female', 'CMPR_agri_labourers_male', 'CMPR_below_primary_female', 'CMPR_below_primary_male', 'CMPR_cultivators_female', 'CMPR_cultivators_male', 'CMPR_household_industry_female', 'CMPR_household_industry_male', 'CMPR_illiterate_female', 'CMPR_illiterate_male', 'CMPR_main_workers_female', 'CMPR_main_workers_male', 'CMPR_matric_female', 'CMPR_matric_male', 'CMPR_middle_female', 'CMPR_middle_male', 'CMPR_non_workers_female', 'CMPR_non_workers_male', 'CMPR_other_workers_female', 'CMPR_other_workers_male', 'CMPR_primary_female', 'CMPR_primary_male', 'CMPR_total_female', 'CMPR_total_male', 'Illiteracy_rate_total_female', 'Illiteracy_rate_total_male', 'Literacy_rate_total_female', 'Literacy_rate_total_male']

# %%
"""
Append Religion-Specific CMPR to df_religion_state_2001.csv
=============================================================
The original df_religion_state_2001.csv has no CMPR columns.
This script computes them from C-03_Appendix_states.csv (raw 2001 census)
and saves an updated version of the file WITH the CMPR columns appended.

Formula:
    CMPR = (married females/males under 18) / (total females/males under 18) × 1000

Age group used: 'Less than 18' → maps to age_14_17 bracket in your pipeline.

HOW TO RUN:
    python3 append_religion_cmpr_2001.py

Output:
    output_datasets_2001/df_religion_state_2001.csv  ← updated IN PLACE
    (a backup is saved as df_religion_state_2001_backup.csv first)
"""

import os
import shutil
import pandas as pd

# ── Paths ──────────────────────────────────────────────────────────────────────
REL_PATH_2001     = 'output_datasets_2001/df_religion_state_2001.csv'
RAW_2001_APPENDIX = 'raw_data/2001/C-03_Appendix_states.csv'
BACKUP_PATH       = 'output_datasets_2001/df_religion_state_2001_backup.csv'


def compute_religion_cmpr_2001(raw_path):
    """
    Compute religion-specific CMPR per 1000 from C-03_Appendix_states.csv.
    Returns wide DataFrame: state_code + CMPR_{religion}_{female/male} columns.
    """
    df_raw = pd.read_csv(raw_path)

    religions = ['Hindu', 'Muslim', 'Christian', 'Sikh', 'Buddhist', 'Jain']

    df_f = df_raw[
        (df_raw['Total/ | Rural/ | Urban/'] == 'Total') &
        (df_raw['Age- | group | 1'] == 'Less than 18') &
        (df_raw['Religion'].isin(religions))
    ].copy()

    df_f['state_code'] = df_f['State | Code'].astype(int)
    df_f['CMPR_female'] = (df_f['Females | 10'] / df_f['Females | 4'] * 1000).round(4)
    df_f['CMPR_male']   = (df_f['Males | 9']    / df_f['Males | 3']   * 1000).round(4)
    df_f['rel'] = df_f['Religion'].str.lower()

    cmpr_wide = df_f.pivot_table(
        index='state_code', columns='rel',
        values=['CMPR_female', 'CMPR_male'], aggfunc='first'
    )
    cmpr_wide.columns = [
        f'CMPR_{rel}_{g.split("_")[1]}' for g, rel in cmpr_wide.columns
    ]
    return cmpr_wide.reset_index()


def main():
    print("\n" + "="*60)
    print("  Appending Religion CMPR to df_religion_state_2001.csv")
    print("="*60)

    # ── Load original file ──────────────────────────────────────────────────
    df_rel = pd.read_csv(REL_PATH_2001)
    print(f"\n  Original file: {REL_PATH_2001}")
    print(f"  Shape: {df_rel.shape}")
    print(f"  Columns ({len(df_rel.columns)}): {df_rel.columns.tolist()}")

    # ── Check for existing CMPR columns ────────────────────────────────────
    existing_cmpr = [c for c in df_rel.columns if c.startswith('CMPR_')]
    if existing_cmpr:
        print(f"\n  ⚠  File already has CMPR columns: {existing_cmpr}")
        print("  These will be replaced with freshly computed values.")
        df_rel = df_rel.drop(columns=existing_cmpr)

    # ── Back up original ────────────────────────────────────────────────────
    shutil.copy(REL_PATH_2001, BACKUP_PATH)
    print(f"\n  Backup saved to: {BACKUP_PATH}")

    # ── Compute CMPR ────────────────────────────────────────────────────────
    print(f"\n  Computing CMPR from: {RAW_2001_APPENDIX}")
    cmpr_wide = compute_religion_cmpr_2001(RAW_2001_APPENDIX)

    cmpr_cols = [c for c in cmpr_wide.columns if c != 'state_code']
    print(f"\n  CMPR columns computed ({len(cmpr_cols)}):")
    for c in sorted(cmpr_cols):
        print(f"    {c}")

    # ── Merge ───────────────────────────────────────────────────────────────
    df_updated = df_rel.merge(cmpr_wide, on='state_code', how='left')

    # Verify merge quality
    n_matched = df_updated[cmpr_cols[0]].notna().sum()
    n_total   = len(df_updated)
    print(f"\n  Merge result: {n_matched}/{n_total} rows matched on state_code")

    unmatched = df_updated[df_updated[cmpr_cols[0]].isna()]['state_name'].unique()
    if len(unmatched) > 0:
        print(f"  ⚠  Unmatched state_names (no CMPR computed): {list(unmatched)}")

    # ── Save updated file ───────────────────────────────────────────────────
    df_updated.to_csv(REL_PATH_2001, index=False)

    print(f"\n  ✓ Updated file saved: {REL_PATH_2001}")
    print(f"  New shape: {df_updated.shape}")
    print(f"  New columns ({len(df_updated.columns)}):")
    print(f"    {df_updated.columns.tolist()}")

    # ── Sanity check: show a few CMPR values ───────────────────────────────
    print("\n  Sample CMPR values (age_14_17, first 5 states):")
    sample = df_updated[
        df_updated['age_bracket'] == 'age_14_17'
    ][['state_name'] + sorted(cmpr_cols)].head(5)
    print(sample.to_string(index=False))

    print("\n" + "="*60)
    print("  Done. Original backed up, updated file saved in place.")
    print("="*60)


if __name__ == '__main__':
    main()
# Out:
# ============================================================
#   Appending Religion CMPR to df_religion_state_2001.csv
# ============================================================
#
#   Original file: output_datasets_2001/df_religion_state_2001.csv
#   Shape: (144, 39)
#   Columns (39): ['state_name', 'age_bracket', 'state_code', 'Below_primary_share_buddhist_female', 'Below_primary_share_christian_female', 'Below_primary_share_hindu_female', 'Below_primary_share_jain_female', 'Below_primary_share_muslim_female', 'Below_primary_share_sikh_female', 'Illiteracy_rate_buddhist_female', 'Illiteracy_rate_buddhist_male', 'Illiteracy_rate_christian_female', 'Illiteracy_rate_christian_male', 'Illiteracy_rate_hindu_female', 'Illiteracy_rate_hindu_male', 'Illiteracy_rate_jain_female', 'Illiteracy_rate_jain_male', 'Illiteracy_rate_muslim_female', 'Illiteracy_rate_muslim_male', 'Illiteracy_rate_sikh_female', 'Illiteracy_rate_sikh_male', 'Literacy_rate_buddhist_female', 'Literacy_rate_buddhist_male', 'Literacy_rate_christian_female', 'Literacy_rate_christian_male', 'Literacy_rate_hindu_female', 'Literacy_rate_hindu_male', 'Literacy_rate_jain_female', 'Literacy_rate_jain_male', 'Literacy_rate_muslim_female', 'Literacy_rate_muslim_male', 'Literacy_rate_sikh_female', 'Literacy_rate_sikh_male', 'Middle_school_share_buddhist_female', 'Middle_school_share_christian_female', 'Middle_school_share_hindu_female', 'Middle_school_share_jain_female', 'Middle_school_share_muslim_female', 'Middle_school_share_sikh_female']
#
#   Backup saved to: output_datasets_2001/df_religion_state_2001_backup.csv
#
#   Computing CMPR from: raw_data/2001/C-03_Appendix_states.csv
#
#   CMPR columns computed (12):
#     CMPR_buddhist_female
#     CMPR_buddhist_male
#     CMPR_christian_female
#     CMPR_christian_male
#     CMPR_hindu_female
#     CMPR_hindu_male
#     CMPR_jain_female
#     CMPR_jain_male
#     CMPR_muslim_female
#     CMPR_muslim_male
#     CMPR_sikh_female
#     CMPR_sikh_male
#
#   Merge result: 136/144 rows matched on state_code
#   ⚠  Unmatched state_names (no CMPR computed): ['INDIA', 'Lakshadweep']
#
#   ✓ Updated file saved: output_datasets_2001/df_religion_state_2001.csv
#   New shape: (144, 51)
#   New columns (51):
#     ['state_name', 'age_bracket', 'state_code', 'Below_primary_share_buddhist_female', 'Below_primary_share_christian_female', 'Below_primary_share_hindu_female', 'Below_primary_share_jain_female', 'Below_primary_share_muslim_female', 'Below_primary_share_sikh_female', 'Illiteracy_rate_buddhist_female', 'Illiteracy_rate_buddhist_male', 'Illiteracy_rate_christian_female', 'Illiteracy_rate_christian_male', 'Illiteracy_rate_hindu_female', 'Illiteracy_rate_hindu_male', 'Illiteracy_rate_jain_female', 'Illiteracy_rate_jain_male', 'Illiteracy_rate_muslim_female', 'Illiteracy_rate_muslim_male', 'Illiteracy_rate_sikh_female', 'Illiteracy_rate_sikh_male', 'Literacy_rate_buddhist_female', 'Literacy_rate_buddhist_male', 'Literacy_rate_christian_female', 'Literacy_rate_christian_male', 'Literacy_rate_hindu_female', 'Literacy_rate_hindu_male', 'Literacy_rate_jain_female', 'Literacy_rate_jain_male', 'Literacy_rate_muslim_female', 'Literacy_rate_muslim_male', 'Literacy_rate_sikh_female', 'Literacy_rate_sikh_male', 'Middle_school_share_buddhist_female', 'Middle_school_share_christian_female', 'Middle_school_share_hindu_female', 'Middle_school_share_jain_female', 'Middle_school_share_muslim_female', 'Middle_school_share_sikh_female', 'CMPR_buddhist_female', 'CMPR_christian_female', 'CMPR_hindu_female', 'CMPR_jain_female', 'CMPR_muslim_female', 'CMPR_sikh_female', 'CMPR_buddhist_male', 'CMPR_christian_male', 'CMPR_hindu_male', 'CMPR_jain_male', 'CMPR_muslim_male', 'CMPR_sikh_male']
#
#   Sample CMPR values (age_14_17, first 5 states):
#       state_name  CMPR_buddhist_female  CMPR_buddhist_male  CMPR_christian_female  CMPR_christian_male  CMPR_hindu_female  CMPR_hindu_male  CMPR_jain_female  CMPR_jain_male  CMPR_muslim_female  CMPR_muslim_male  CMPR_sikh_female  CMPR_sikh_male
#            INDIA                   NaN                 NaN                    NaN                  NaN                NaN              NaN               NaN             NaN                 NaN               NaN               NaN             NaN
#  Jammu & Kashmir               15.2513              5.8386                18.3639              10.8141            17.3726           7.8584           15.8730         11.8203             22.0797            8.2823           21.2588          9.0046
# Himachal Pradesh               10.0109              5.2043                14.7541               4.7393             8.3876           3.3100           15.3061          0.0000             11.4295            5.7517            7.9510          3.3201
#           Punjab               15.7182              9.2214                14.5790               7.3994            16.6972           9.1504           18.2927         11.0431             16.8774            9.8932           16.4047          8.3585
#       Chandigarh               16.3934              4.6512                14.9007               1.5736            12.4727           5.6116           19.5531          2.5126             11.1355            7.1136           11.6013          3.8254
#
# ============================================================
#   Done. Original backed up, updated file saved in place.
# ============================================================
